# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

train = pd.read_csv(r'Border_Crossing_Entry_Data.csv')
train['State'].unique()
# Out:
# array(['California', 'Maine', 'Arizona', 'New York', 'North Dakota',
#        'Texas', 'Montana', 'Minnesota', 'Vermont', 'Washington', 'Idaho',
#        'Michigan', 'New Mexico', 'Alaska', 'Ohio'], dtype=object)

# %%
def transfor(x):
# for x in train['Date']:
    tmp_year = x.split('/')[2]
    return tmp_year.split(' ')[0]
train['year'] = train['Date'].apply(transfor)
train['year'].value_counts()
# Out:
# 2010    16200
# 2005    16128
# 2006    16128
# 2008    16056
# 2007    16056
# 2009    16056
# 2004    15984
# 2015    15984
# 2013    15840
# 2012    15840
# 2011    15840
# 2014    15840
# 2003    15588
# 1999    14832
# 1998    14832
# 1997    14832
# 2002    14832
# 2000    14832
# 1996    14832
# 2001    14832
# 2016    13754
# 2017     9717
# 2018     9534
# 2019     2364
# Name: year, dtype: int64

# %%
def stat(x):
    t = x.split(' ')
    if len(t) > 1:
        return t[0]+'_'+t[1]
    return t[0]
train['un_State'] = train['State'].apply(stat)
train['State'].unique()
# Out:
# array(['California', 'Maine', 'Arizona', 'New York', 'North Dakota',
#        'Texas', 'Montana', 'Minnesota', 'Vermont', 'Washington', 'Idaho',
#        'Michigan', 'New Mexico', 'Alaska', 'Ohio'], dtype=object)

# %%
p_s=[]
for y in train['year'].unique():
#     print(y)
    for s in train['un_State'].unique():
        port_unique = train[train['un_State'] == s]['Port Name'].unique()
#         print(s, port_unique)
        for p in port_unique:
            tmp = train[(train['un_State'] == s) & (train['Port Name'] == p) & (train['year'] == y)]['Value'].sum()
#             print(s, p, tmp,y)
            if tmp > 2500000:
                p_s.append({'port':p,'state':s,'value':tmp ,'year':y})
print(p_s)
# Out:
# [{'port': 'Calexico East', 'state': 'California', 'value': 2491920, 'year': '2019'}, {'port': 'Otay Mesa', 'state': 'California', 'value': 5750126, 'year': '2019'}, {'port': 'San Ysidro', 'state': 'California', 'value': 11720414, 'year': '2019'}, {'port': 'Calexico', 'state': 'California', 'value': 4337948, 'year': '2019'}, {'port': 'Nogales', 'state': 'Arizona', 'value': 3506718, 'year': '2019'}, {'port': 'San Luis', 'state': 'Arizona', 'value': 2812396, 'year': '2019'}, {'port': 'Buffalo-Niagara Falls', 'state': 'New_York', 'value': 3275570, 'year': '2019'}, {'port': 'Eagle Pass', 'state': 'Texas', 'value': 2570213, 'year': '2019'}, {'port': 'El Paso', 'state': 'Texas', 'value': 10227200, 'year': '2019'}, {'port': 'Hidalgo', 'state': 'Texas', 'value': 4293346, 'year': '2019'}, {'port': 'Brownsville', 'state': 'Texas', 'value': 4380536, 'year': '2019'}, {'port': 'Laredo', 'state': 'Texas', 'value': 6336240, 'year': '2019'}, {'port': 'Blaine', 'state': 'Washington', 'value': 2774470, 'year': '2019'}, {'port': 'Detroit', 'state': 'Michigan', 'value': 3277181, 'year': '2019'}, {'port': 'Calexico East', 'state': 'California', 'value': 11236590, 'year': '2018'}, {'port': 'Otay Mesa', 'state': 'California', 'value': 26411957, 'year': '2018'}, {'port': 'San Ysidro', 'state': 'California', 'value': 49208743, 'year': '2018'}, {'port': 'Tecate', 'state': 'California', 'value': 4187111, 'year': '2018'}, {'port': 'Calexico', 'state': 'California', 'value': 16971417, 'year': '2018'}, {'port': 'Andrade', 'state': 'California', 'value': 2596157, 'year': '2018'}, {'port': 'Calais', 'state': 'Maine', 'value': 1932962, 'year': '2018'}, {'port': 'Nogales', 'state': 'Arizona', 'value': 15139737, 'year': '2018'}, {'port': 'Douglas', 'state': 'Arizona', 'value': 5756722, 'year': '2018'}, {'port': 'Lukeville', 'state': 'Arizona', 'value': 1522840, 'year': '2018'}, {'port': 'San Luis', 'state': 'Arizona', 'value': 11810867, 'year': '2018'}, {'port': 'Champlain-Rouses Point', 'state': 'New_York', 'value': 4369090, 'year': '2018'}, {'port': 'Massena', 'state': 'New_York', 'value': 2485147, 'year': '2018'}, {'port': 'Buffalo-Niagara Falls', 'state': 'New_York', 'value': 18541241, 'year': '2018'}, {'port': 'Alexandria Bay', 'state': 'New_York', 'value': 2275133, 'year': '2018'}, {'port': 'Progreso', 'state': 'Texas', 'value': 5236568, 'year': '2018'}, {'port': 'Roma', 'state': 'Texas', 'value': 2546333, 'year': '2018'}, {'port': 'Del Rio', 'state': 'Texas', 'value': 5124690, 'year': '2018'}, {'port': 'Eagle Pass', 'state': 'Texas', 'value': 10169946, 'year': '2018'}, {'port': 'El Paso', 'state': 'Texas', 'value': 43778742, 'year': '2018'}, {'port': 'Hidalgo', 'state': 'Texas', 'value': 17303701, 'year': '2018'}, {'port': 'Brownsville', 'state': 'Texas', 'value': 18336697, 'year': '2018'}, {'port': 'Presidio', 'state': 'Texas', 'value': 2495846, 'year': '2018'}, {'port': 'Laredo', 'state': 'Texas', 'value': 25396401, 'year': '2018'}, {'port': 'International Falls-Ranier', 'state': 'Minnesota', 'value': 1977900, 'year': '2018'}, {'port': 'Derby Line', 'state': 'Vermont', 'value': 1703718, 'year': '2018'}, {'port': 'Highgate Springs-Alburg', 'state': 'Vermont', 'value': 1815654, 'year': '2018'}, {'port': 'Lynden', 'state': 'Washington', 'value': 1805013, 'year': '2018'}, {'port': 'Blaine', 'state': 'Washington', 'value': 13632952, 'year': '2018'}, {'port': 'Sumas', 'state': 'Washington', 'value': 2935526, 'year': '2018'}, {'port': 'Point Roberts', 'state': 'Washington', 'value': 2594824, 'year': '2018'}, {'port': 'Sault Sainte Marie', 'state': 'Michigan', 'value': 2103600, 'year': '2018'}, {'port': 'Port Huron', 'state': 'Michigan', 'value': 6758067, 'year': '2018'}, {'port': 'Detroit', 'state': 'Michigan', 'value': 14148093, 'year': '2018'}, {'port': 'Santa Teresa', 'state': 'New_Mexico', 'value': 2083662, 'year': '2018'}, {'port': 'Calexico East', 'state': 'California', 'value': 12163690, 'year': '2017'}, {'port': 'Otay Mesa', 'state': 'California', 'val ...

# %%
df3 = pd.DataFrame.from_dict(p_s)
df3.to_csv('train2019.csv', index=False)
